# %% [markdown]
# <a href="https://colab.research.google.com/github/qkbaltazar25-hash/CPE009A---Object-Oriented-Programming-1/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Indentation

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# Python Comments

# %%
#This is a comment
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# Variable Naming Conventions

# %%
myvar="John"
_my_var="John"
myVar="John"

# %% [markdown]
# Python Variable

# %%
x=1
a, b=0,-1
a, b, c=0,-1,2

b="Sally" #This is a type of string

# %% [markdown]
# Casting

# %%
b="sally" #This is a type of string
b=int(4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type() function

# %%
x=5
y="John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# "Double quotes" or 'Single' quotes

# %%
y="John"
y='John'

# %% [markdown]
# Case sensitive

# %%
a=4
A="Sally"
#A will not overwrite a

# %% [markdown]
# Multiple Variables

# %%
x, y, z="one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three
