# %% [markdown]
# <a href="https://colab.research.google.com/github/qkbaltazar25-hash/CPE009A---CPE12S2---OOP1/blob/main/Baltazar_CPE009_S1_Seatwork_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We want to create a python code for a grading scheme

# Create a function to accept a number of activities
# Compute for the score vs total
# Return the average grade of the student in %
def termCrit(actNumber):
    rawScore = 0
    totalScore = 0

    for i in range(actNumber):
        while True:
            score = float(input("Score: "))
            total = float(input("Total: "))

            if score <= total and total > 0:
                rawScore += score
                totalScore += total
                break
            else:
                print("\nInvalid Scores.\n")

    if totalScore == 0:
        return 0

    return (rawScore / totalScore) * 100

# %%
# Create a function for the class standing per term
def termCS():
  print("Hands-on Activities: ")
  termHOA = termCrit(int(input("How many hands-on activities this term? ")))

  print("Quizzes:")
  termQuiz = termCrit(int(input("How many quizzes this term? ")))

  print("Assignment: ")
  termAss = termCrit(int(input("How many assignments? ")))

  grade = (0.5 * termHOA) + (0.3 * termQuiz) + (0.2 * termAss)

  print("Total grade for CS is: ", grade)
  return grade

# %%
# Create a function to compute the term grade
def termGrade():
  print("Computing for the term grade.")
  examRaw = float(input("Exam Score: "))
  examTotal = float(input("Exam Total: "))
  examGrade = (examRaw/examTotal) * 100
  print("Total exam grade is: ", examGrade)

  CSgrade = termCS()

  grade = (0.5 * examGrade) + (0.5 * CSgrade)
  print("Total grade for the term is: ", grade)
  return grade

# %%
# Create a function to compute for the grades in the semester
def semesterGrade():
  print("Prelim Grade")

  prelimGrade = termGrade()

  print("")
  print("Midterm Grade")
  midtermGrade = termGrade()
  finalMG = (1/3)*prelimGrade + (2/3)*midtermGrade

  print("")
  print("Final Grade")
  finalGrade = termGrade()
  finalFG = (1/3)*finalMG + (2/3)*finalGrade

  return finalFG

# %%
def convertGrade(finalFG):
  if 99 <= finalFG <= 100:
    print("T.I.P.s Grade: 1.00")
  elif 95 < finalFG < 99:
    print("T.I.P.s Grade: 1.25")
  elif 92 < finalFG < 96:
    print("T.I.P.s Grade: 1.50")
  elif 89 < finalFG < 93:
    print("T.I.P.s Grade: 1.75")
  elif 86 < finalFG < 90:
    print("T.I.P.s Grade: 2.00")
  elif 83 < finalFG < 87:
    print("T.I.P.s Grade: 2.25")
  elif 80 < finalFG < 84:
    print("T.I.P.s Grade: 2.50")
  elif 77 < finalFG < 81:
    print("T.I.P.s Grade: 2.75")
  elif 74 < finalFG < 78:
    print("T.I.P.s Grade: 3.00")
  else:
    print("T.I.P.s Grade: 5.00")
  #The class should add everything else

# %%
4#Driver Code

# Trial 1
print(convertGrade(semesterGrade()))
# Trial 2

# Trial 3
# Out:
# Prelim Grade
# Computing for the term grade.
# Exam Score: 56
# Exam Total: 60
# Total exam grade is:  93.33333333333333
# Hands-on Activities:
# How many hands-on activities this term? 1
# Score: 20
# Total: 20
# Quizzes:
# How many quizzes this term? 1
# Score: 15
# Total: 15
# Assignment:
# How many assignments? 1
# Score: 35
# Total: 40
# Total grade for CS is:  97.5
# Total grade for the term is:  95.41666666666666
#
# Midterm Grade
# Computing for the term grade.
# Exam Score: 60
# Exam Total: 60
# Total exam grade is:  100.0
# Hands-on Activities:
# How many hands-on activities this term? 1
# Score: 20
# Total: 20
# Quizzes:
# How many quizzes this term? 1
# Score: 15
# Total: 15
# Assignment:
# How many assignments? 1
# Score: 40
# Total: 40
# Total grade for CS is:  100.0
# Total grade for the term is:  100.0
#
# Final Grade
# Computing for the term grade.
# Exam Score: 50
# Exam Total: 60
# Total exam grade is:  83.33333333333334
# Hands-on Activities:
# ...

# %% [markdown]
# **What is the difference from the code you created?**
#
#
#
# The code that I created helps the code become more detailed which diplays the grades each term for CS and exams. Additionally, while not much has been changed, the changed function was in termCrit where I changed the array null to just 0 and also changed some syntaxes to which can help the function run more smoothly by adding the correct amount of totals.
# <Answer here>
